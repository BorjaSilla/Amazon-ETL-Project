# %% [markdown]
# # Amazon Web Scraping: Bestsellers by Category 🛒

# %%
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
import warnings
warnings.filterwarnings('ignore')
import asyncio
from tqdm.notebook import tqdm

# %% [markdown]
# Some options for the webdriver

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = webdriver.Chrome(opciones)
url = 'https://www.amazon.es/gp/bestsellers'

driver.get(url)

time.sleep(2)

# Cookies
aceptar = driver.find_element(By.XPATH, '//*[@id="sp-cc-rejectall-link"]')
aceptar.click()

# Locate the div element by its class and ID
div_element = driver.find_element(By.CLASS_NAME, "_p13n-zg-nav-tree-all_style_zg-browse-root__-jwNv")
link_elements = div_element.find_elements(By.TAG_NAME, 'a')
links = [link.get_attribute('href') for link in link_elements]


driver.quit()

# %%
links[:]
# Out:
# ['https://www.amazon.es/gp/bestsellers/grocery/ref=zg_bs_nav_grocery_0',
#  'https://www.amazon.es/gp/bestsellers/boost/ref=zg_bs_nav_boost_0',
#  'https://www.amazon.es/gp/bestsellers/amazon-renewed/ref=zg_bs_nav_amazon-renewed_0',
#  'https://www.amazon.es/gp/bestsellers/mobile-apps/ref=zg_bs_nav_mobile-apps_0',
#  'https://www.amazon.es/gp/bestsellers/baby/ref=zg_bs_nav_baby_0',
#  'https://www.amazon.es/gp/bestsellers/beauty/ref=zg_bs_nav_beauty_0',
#  'https://www.amazon.es/gp/bestsellers/tools/ref=zg_bs_nav_tools_0',
#  'https://www.amazon.es/gp/bestsellers/music/ref=zg_bs_nav_music_0',
#  'https://www.amazon.es/gp/bestsellers/gift-cards/ref=zg_bs_nav_gift-cards_0',
#  'https://www.amazon.es/gp/bestsellers/climate-pledge/ref=zg_bs_nav_climate-pledge_0',
#  'https://www.amazon.es/gp/bestsellers/automotive/ref=zg_bs_nav_automotive_0',
#  'https://www.amazon.es/gp/bestsellers/sports/ref=zg_bs_nav_sports_0',
#  'https://www.amazon.es/gp/bestsellers/amazon-devices/ref=zg_bs_nav_amazon-devices_0',
#  'https://www.amazon.es/gp/bestsellers/electronics/ref=zg_bs_nav_electronics_0',
#  'https://www.amazon.es/gp/bestsellers/luggage/ref=zg_bs_nav_luggage_0',
#  'https://www.amazon.es/gp/bestsellers/appliances/ref=zg_bs_nav_appliances_0',
#  'https://www.amazon.es/gp/bestsellers/kitchen/ref=zg_bs_nav_kitchen_0',
#  'https://www.amazon.es/gp/bestsellers/lighting/ref=zg_bs_nav_lighting_0',
#  'https://www.amazon.es/gp/bestsellers/industrial/ref=zg_bs_nav_industrial_0',
#  'https://www.amazon.es/gp/bestsellers/computers/ref=zg_bs_nav_computers_0',
#  'https://www.amazon.es/gp/bestsellers/musical-instruments/ref=zg_bs_nav_musical-instruments_0',
#  'https://www.amazon.es/gp/bestsellers/lawn-garden/ref=zg_bs_nav_lawn-garden_0',
#  'https://www.amazon.es/gp/bestsellers/toys/ref=zg_bs_nav_toys_0',
#  'https://www.amazon.es/gp/bestsellers/books/ref=zg_bs_nav_books_0',
#  'https://www.amazon.es/gp/bestsellers/fashion/ref=zg_bs_nav_fashion_0',
#  'https://www.amazon.es/gp/bestsellers/dmusic/ref=zg_bs_nav_dmusic_0',
#  'https://www.amazon.es/gp/bestsellers/office/ref=zg_bs_nav_office_0',
#  'https://www.amazon.es/gp/bestsellers/dvd/ref=zg_bs_nav_dvd_0',
#  'https://www.amazon.es/gp/bestsellers/handmade/ref=zg_bs_nav_handmade_0',
#  'https://www.amazon.es/gp/bestsellers/pet-supplies/ref=zg_bs_nav_pet-supplies_0',
#  'https://www.amazon.es/gp/bestsellers/hpc/ref=zg_bs_nav_hpc_0',
#  'https://www.amazon.es/gp/bestsellers/software/ref=zg_bs_nav_software_0',
#  'https://www.amazon.es/gp/bestsellers/digital-text/ref=zg_bs_nav_digital-text_0',
#  'https://www.amazon.es/gp/bestsellers/videogames/ref=zg_bs_nav_videogames_0']

# %%
len(links)
# Out:
# 34

# %% [markdown]
# Scraping groceries

# %%
url = 'https://www.amazon.es/gp/bestsellers/grocery/ref=zg_bs_nav_grocery_0'

DATOS=[]
CABECERAS=[]

# %%
# Step 1: Start a driver instance
driver = webdriver.Chrome()
driver.get(url)

#Step 2: Close cookies popup - if needed

try: 
    driver.find_element(By.XPATH, '//*[@id="sp-cc-accept"]').click()
    time.sleep(1)
except:
    print(f"Cookies not needed")

# Step 3: Scroll to the end of the website
# driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# Step 4: Find product container and save it
caja_productos = driver.find_elements(By.CLASS_NAME, 'a-cardui._cDEzb_grid-cell_1uMOS.expandableGrid.p13n-grid-content')

# Step 5: Data Extraction:
rank = [int(i.text.split('\n')[0].split('#')[1]) for i in caja_productos]
titulos = [i.text.split('\n')[1] for i in caja_productos]
precio = []
num_reviews = [int(i.text.split('\n')[2].replace('.', '')) for i in caja_productos]

for e in caja_productos:
    try:
        precio_text = e.text.split('\n')[3]
        precio_value = float(precio_text.split()[0].replace(',', '.'))
        precio.append(precio_value)
    except:
        precio.append(0)

rating_elements = driver.find_elements(By.CSS_SELECTOR, "i.a-icon-star-small span.a-icon-alt")
ratings = [rating.get_attribute("textContent").split(" de ")[0] for rating in rating_elements]

# %% [markdown]
# Scraping Images

# %%
image_elements = driver.find_elements(By.CSS_SELECTOR, "div[data-asin] a.a-link-normal img.a-dynamic-image")
image_links = [image.get_attribute("src") for image in image_elements]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Step 1: Start a driver instance
driver = webdriver.Chrome()
url = "https://www.amazon.es/gp/bestsellers/grocery/6347831031/ref=zg_bs_nav_grocery_1"
driver.get(url)

# Step 2: Close cookies popup - if needed
try:
    driver.find_element(By.XPATH, '//*[@id="sp-cc-accept"]').click()
    time.sleep(1)
except:
    print("Cookies not needed")

# Step 3: Scroll to the end of the website to load all elements
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# Step 4: Find product container and save it
caja_productos = driver.find_elements(By.CLASS_NAME, 'a-cardui._cDEzb_grid-cell_1uMOS.expandableGrid.p13n-grid-content')

# Step 5: Data Extraction
rank = [int(i.text.split('\n')[0].split('#')[1]) for i in caja_productos]
titulos = [i.text.split('\n')[1] for i in caja_productos]
precio = []
num_reviews = [int(i.text.split('\n')[2].replace('.', '')) for i in caja_productos]

for e in caja_productos:
    try:
        precio_text = e.text.split('\n')[3]
        precio_value = float(precio_text.split()[0].replace(',', '.'))
        precio.append(precio_value)
    except:
        precio.append(0)

rating_elements = driver.find_elements(By.CSS_SELECTOR, "i.a-icon-star-small span.a-icon-alt")
ratings = [rating.get_attribute("textContent").split(" de ")[0] for rating in rating_elements]

image_elements = driver.find_elements(By.CSS_SELECTOR, "div[data-asin] a.a-link-normal img.a-dynamic-image")
image_links = [image.get_attribute("src") for image in image_elements]


time.sleep(2)

//*[@id="CardInstanceivKun2BDSxhVFrrzzESDbQ"]/div[2]/div[2]/ul/li[4]/a

# Close the webdriver when you're done
driver.quit()

# Create a dictionary from your lists
data = {
    'rank': rank,
    'title': titulos,
    'price': precio,
    'rating': ratings,
    'num_reviews': num_reviews,
    'img_link': image_links
}

# Create a DataFrame
df = pd.DataFrame(data, columns=['rank', 'title', 'price', 'rating', 'num_reviews', 'img_link'])
df

# %%
df
# Out:
#     rank                                              title  price rating  \
# 0      1  Blemil 2 Optimum ProTech - Leche de continuaci...    2.0    4,7
# 1      2  Blevit Plus Bibe 8 Cereales - Papilla de Cerea...    8.0    4,7
# 2      3  Blemil Confort ProTech - Fórmula de Inicio en ...    2.0    4,6
# 3      4  Blemil 1 Optimum ProTech 3PACK | Leche de Inic...    1.0    4,0
# 4      5  Nutribén Innova 2 - Leche de Fórmula en Polvo ...   10.0    4,7
# 5      6  Blemil 2 Optimum ProTech - Leche de continuaci...    3.0    4,8
# 6      7  Blevit Plus Duplo 8 Cereales y Galletas María ...    2.0    4,7
# 7      8  Almirón Profutura 1 Leche de Inicio en Polvo, ...   17.0    4,8
# 8      9  Blevit Plus Superfibra 8 Cereales - Papilla de...    5.0    4,6
# 9     10  Blevit Barriguitas Felices - Infusión digestiv...   11.0    4,6
# 10    11  Nutribén Potitos De Verduritas con Lenguado, D...    1.0    4,5
# 11    12       Nutribén Papilla Instantánea 8 Cereales, 1kg    5.0    4,5
# 12    13  Nutribén Continuación Pro Alfa 2 - Leche en Po...    9.0    4,7
# 13    14  PSmileat - Papilla Ecológica 7 Cereales, Ingre...    1.0    4,5
# 14    15  Nestlé Nan Optipro 1 Leche para Lactantes en P...   11.0    4,6
# 15    16  Puleva Peques Leche de Crecimiento Tipo 3, 1 L...    5.0    4,5
# 16    17  Smileat - Panecitos Multicereales Ecológicos, ...    1.0    4,0
# 17    18  Nestlé Nan Optipro 2 Leche de Continuación en ...    2.0    4,7
# 18    19  Nutribén Natal Pro Alfa 1 - Leche en Polvo Beb...    8.0    4,6
# 19    20  Almirón Profutura 2 Leche de Continuación en P...    9.0    4,7
# 20    21  Nutribén Potitos De Menestra De Cordero, Desde...    1.0    4,6
# 21    22  Almirón Advance Digest 1, Leche de Inicio Bebé...    4.0    4,5
# 22    23  Nutribén Innova 1 - Leche en Polvo | Fórmula p...   13.0    4,7
# 23    24  Nutribén Confort - Leche en Polvo Bebé AntiCól...    6.0    4,5
# 24    25  Enfamil Complete 2 Leche de Continuación en Po...   10.0    4,7
# 25    26  Nestlé NAN Supreme Pro 2 Leche de Continuación...   14.0    4,5
# 26    27  Almirón, Galletas para Bebé Sin Gluten, a part...    7.0    4,5
# 27    28  Nestlé Nan Supremepro 1 Leche para Lactantes e...    5.0    4,6
# 28    29  Nutribén Potitos | Tarrito de Menestra de Verd...    1.0    4,7
# 29    30  NESTLÉ NATIVA 3, Líquido, Crecimiento Original...    1.0    4,6
# 30    31  Puleva Peques Leche De Crecimiento Tipo 3 con ...    1.0    4,5
# 31    32  Blemil Plus 1 Forte - Leche de Inicio en polvo...   18.0    4,6
# 32    33  Smileat | Galletas Ecológicas de Cacao, Avena ...    1.0    4,0
# 33    34  Blevit Plus Bibe 8 Cereales y ColaCao - Papill...    7.0    4,6
# 34    35  Almirón Advance 2 Leche De Continuación En Pol...    8.0    4,7
# 35    36  Almirón Advance Digest 2 Leche Fórmula En Polv...   18.0    4,6
# 36    37  Nestlé Leche y Cereales con Miel Pijama - Paqu...    1.0    4,6
# 37    38  Almirón Advance 1 Leche De Inicio En Polvo, A ...   20.0    4,6
# 38    39  Blemil 1 Optimum Evolution - Leche para Lactan...    1.0    4,7
# 39    40  Marca Amazon - Mama Bear Bolsitas de Puré de M...    1.0    4,5
# 40    41  Hero Baby - Tarritos de Verduritas con Pollo y...    1.0    4,5
# 41    42  Nestlé Nidina 2 Leche de Continuación en Polvo...    9.0    4,7
# 42    43  Blemil Plus 3 Crecimiento 0% Azúcares Añadidos...    6.0    4,7
# 43    44          NESTLÉ Pure Happy Fruits 110g - Pack de 8    1.0    4,6
# 44    45  Almirón Advance 2, Leche de Continuación en Po...    8.0    4,7
# 45    46  Enfamil Confort Fórmula para Bebés con Trastor...   10.0    4,5
# 46    47  Enfamil Complete 1 Leche infantil para lactant...    6.0    4,6
# 47    48  Almirón Advance 3, Leche de Crecimiento en Pol...   10.0    4,7
# 48    49  BEAR Rollitos de Fruta Sabor Manzana - Ingredi...    1.0    4,2
# 49    50  Almirón Profutura 3 Leche de Crecimiento en Po...    7.0    4,6
#
#     num_reviews                                           img_link
# 0           170  https://images-eu.ssl-images-amazon.com/images...
# 1           583  https://images-eu.ssl-images-amazon.com/images...
# 2           704  https://images-eu.ssl-images-amazon.com/images...
# 3            46  https://images-eu.ssl-images-amazon.com/images...
# 4           629  https://images-eu.ssl-images-amazon.com/images...
# 5           480  https://images-eu.ssl-images-amazon.com/images...
# 6           475  https://images-eu.ssl-images-amazon.com/images...
# 7           511  https://images-eu.ssl-images-amazon.com/images...
# 8          1064  https://images-eu.ssl-images-amazon.com/images...
# 9          1265  https://images-eu.ssl-images-amazon.com/images...
# 10          360  https://images-eu.ssl-images-amazon.com/images...
# 11          191  https://images-eu.ssl-images-amazon.com/images...
# 12          691  https://images-eu.ssl-images-amazon.com/images...
# 13          207  https://images-eu.ssl-images-amazon.com/images...
# 14          376  https://images-eu.ssl-images-amazon.com/images...
# 15          713  https://images-eu.ssl-images-amazon.com/images...
# 16          528  https://images-eu.ssl-images-amazon.com/images...
# 17          664  https://images-eu.ssl-images-amazon.com/images...
# 18          511  https://images-eu.ssl-images-amazon.com/images...
# 19          395  https://images-eu.ssl-images-amazon.com/images...
# 20          294  https://images-eu.ssl-images-amazon.com/images...
# 21          504  https://images-eu.ssl-images-amazon.com/images...
# 22          737  https://images-eu.ssl-images-amazon.com/images...
# 23          461  https://images-eu.ssl-images-amazon.com/images...
# 24          614  https://images-eu.ssl-images-amazon.com/images...
# 25          130  https://images-eu.ssl-images-amazon.com/images...
# 26          538  https://images-eu.ssl-images-amazon.com/images...
# 27          245  https://images-eu.ssl-images-amazon.com/images...
# 28          216  https://images-eu.ssl-images-amazon.com/images...
# 29          480  https://images-eu.ssl-images-amazon.com/images...
# 30          151  https://images-eu.ssl-images-amazon.com/images...
# 31          968  https://images-eu.ssl-images-amazon.com/images...
# 32            3  https://images-eu.ssl-images-amazon.com/images...
# 33          160  https://images-eu.ssl-images-amazon.com/images...
# 34          407  https://images-eu.ssl-images-amazon.com/images...
# 35          193  https://images-eu.ssl-images-amazon.com/images...
# 36          161  https://images-eu.ssl-images-amazon.com/images...
# 37          560  https://images-eu.ssl-images-amazon.com/images...
# 38          796  https://images-eu.ssl-images-amazon.com/images...
# 39          908  https://images-eu.ssl-images-amazon.com/images...
# 40          426  https://images-eu.ssl-images-amazon.com/images...
# 41          252  https://images-eu.ssl-images-amazon.com/images...
# 42           99  https://images-eu.ssl-images-amazon.com/images...
# 43          126  https://images-eu.ssl-images-amazon.com/images...
# 44          252  https://images-eu.ssl-images-amazon.com/images...
# 45          703  https://images-eu.ssl-images-amazon.com/images...
# 46          593  https://images-eu.ssl-images-amazon.com/images...
# 47          276  https://images-eu.ssl-images-amazon.com/images...
# 48         2378  https://images-eu.ssl-images-amazon.com/images...
# 49           54  https://images-eu.ssl-images-amazon.com/images...
